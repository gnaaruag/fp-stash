# %%
import data
from sklearn.metrics import  classification_report
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x_train = pd.read_csv(r"./x_train.csv")
x_test = pd.read_csv(r"./x_test.csv")
y_train = pd.read_csv(r"./y_train.csv")
y_test = pd.read_csv(r"./y_test.csv")
results_list=data.a

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.tree import plot_tree
from sklearn.metrics import classification_report

# %%
def update(a):
    
    x=[]
    for i in range(len(a[0])):
        counter=0
        for j in range(len(a)):
            if a[j][i] in ('True',1):
                counter+=1
            else:
                counter-=1
        if counter>0:
            x.append(True)
        else:
            x.append(False)
    return(x)
y_pred=update(results_list)

# %%
from sklearn.metrics import roc_curve
prc = roc_curve(y_test, y_pred)
print(prc)
# Out:
# (array([0.   , 0.075, 1.   ]), array([0.        , 0.92105263, 1.        ]), array([2, 1, 0]))

# %%
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(8, 6))  # Adjust figure size as needed
plt.scatter(range(len(y_train)), y_train, label='Training Data', alpha=0.7)
plt.scatter(range(len(y_test)), y_test, label='Testing Data', alpha=0.7)
plt.xlabel('Sample Index')
plt.ylabel('Target Value')
plt.title('Distribution Comparison (Scatter Plot)')
plt.legend()
plt.grid(True)
plt.show()

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
cm = confusion_matrix(y_test, y_pred)
f = sns.heatmap(cm, annot=True, fmt='d')
# Out:
# [[74  6]
#  [ 3 35]]

# %%
y_pred=update(results_list)

report = classification_report(y_test, y_pred)

# Print the classification report
print("Classification Report:\n", report)
# Out:
# Classification Report:
#                precision    recall  f1-score   support
#
#        False       0.96      0.93      0.94        80
#         True       0.85      0.92      0.89        38
#
#     accuracy                           0.92       118
#    macro avg       0.91      0.92      0.91       118
# weighted avg       0.93      0.92      0.92       118
